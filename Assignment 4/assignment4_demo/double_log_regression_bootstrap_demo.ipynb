# %% [markdown]
# # Double Logistic Regression with the Titanic Dataset

# %%
import pandas as pd
import statsmodels.api as sm
import numpy as np

np.random.seed(0)

# Load the Titanic dataset
data = pd.read_csv('titanic.csv')

# Create a binary indicator for the treatment variable (class)
data['class_1st'] = (data['Pclass'] == 1).astype(int)
data['Sex_male'] = (data['Sex'] == 'male').astype(int)
data = data.dropna(subset = ['Survived', 'class_1st', 'SibSp', 'Age', 'Parch', 'Sex_male']).reset_index()

print(len(data))
data.head()
# Out:
# 714
#    index  PassengerId  Survived  Pclass  \
# 0      0            1         0       3
# 1      1            2         1       1
# 2      2            3         1       3
# 3      3            4         1       1
# 4      4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  class_1st  Sex_male
# 0      0         A/5 21171   7.2500   NaN        S          0         1
# 1      0          PC 17599  71.2833   C85        C          1         0
# 2      0  STON/O2. 3101282   7.9250   NaN        S          0         0
# 3      0            113803  53.1000  C123        S          1         0
# 4      0            373450   8.0500   NaN        S          0         1

# %%
data = data[['Survived', 'class_1st', 'SibSp', 'Age', 'Parch', 'Sex_male']]
data.head()
# Out:
#    Survived  class_1st  SibSp   Age  Parch  Sex_male
# 0         0          0      1  22.0      0         1
# 1         1          1      1  38.0      0         0
# 2         1          0      0  26.0      0         0
# 3         1          1      1  35.0      0         0
# 4         0          0      0  35.0      0         1

# %%
# Specify the response and treatment variables
y = data['Survived']
x = data[['class_1st', 'SibSp', 'Age', 'Parch', 'Sex_male']]

# Fit a logistic regression model
model = sm.Logit(y, x)
result = model.fit()

# Print the treatment effect estimates
print(result.params)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.500794
#          Iterations 6
# class_1st    1.751649
# SibSp       -0.046076
# Age          0.003590
# Parch        0.143530
# Sex_male    -2.034606
# dtype: float64

# %% [markdown]
# The output will give you the estimated treatment effects for each covariate in the model. The treatment effect for class_1st (the binary indicator for first-class passengers) represents the difference in the odds of survival between first-class passengers and passengers in other classes, controlling for the effects of age, number of siblings/spouses on board, number of parents/children on board, fare price, and gender.
#
# A positive estimate for the treatment effect of class_1st would indicate that first-class passengers had a higher odds of survival compared to passengers in other classes, while a negative estimate would indicate the opposite. The magnitude of the estimate will give you a sense of how large the difference in odds of survival was between first-class passengers and passengers in other classes, controlling for the other covariates.

# %% [markdown]
# <hr>

# %% [markdown]
# In the first stage, a logistic regression model is fit to predict the probability of the main outcome as a function of the risk factor and other covariates. In the second stage, a logistic regression model is fit to predict the probability of the secondary outcome as a function of the risk factor, other covariates, and the predicted probability of the main outcome from the first stage.
#
# So, double logistic regression is not just fitting two separate logistic regression models, but rather fitting two logistic regression models in two stages, with the results from the first stage being used as a predictor in the second stage.

# %%
model1 = sm.Logit(y, x).fit()
y_hat = np.array(model1.predict(x)).reshape(len(x), 1)
x_new = np.hstack((x, y_hat))
model2 = sm.Logit(y, x_new).fit()
print(model2.params)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.500794
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.464138
#          Iterations 6
# x1    0.774058
# x2   -0.337805
# x3   -0.041707
# x4   -0.191545
# x5   -1.065680
# x6    4.042893
# dtype: float64

# %% [markdown]
# <hr>

# %%
# Define the number of bootstrap resamples
n_resamples = 1000

# Initialize a matrix to store the treatment effect estimates
treat_effects = np.zeros((n_resamples, model2.params.shape[0] - 1))

# Use bootstrapping to estimate the standard error of the treatment effects
i = 0
while i < n_resamples:
    resample_index = np.random.choice(data.index, size = data.index.size, replace = True)
    resample = data.iloc[resample_index]
    x_resample = x.iloc[resample_index]
    y_resample = y.iloc[resample_index]
    model1 = sm.Logit(y_resample, x_resample).fit()
    y_hat = np.array(model1.predict(x_resample)).reshape(len(y_hat), 1)
    x_new = np.hstack((x_resample, y_hat))
    model2 = sm.Logit(y_resample, x_new).fit()
    treat_effects[i, :] = model2.params[:-1]
    i += 1

# Calculate the standard error of the treatment effects
treat_effects_se = treat_effects.std(axis=0)

# Print the standard errors of the treatment effect estimates
print('Standard errors of the treatment effects:')
print(treat_effects_se)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.474510
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.433489
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.475444
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.443791
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.464648
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.444162
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.498589
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.468372
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.495590
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.459258
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.466648
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.432778
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.518106
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.482921
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.513420
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.476268
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.477730
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.449323
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515067
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.473958
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.475535
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.437451
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.522085
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.499127
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.495319
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.465967
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.490937
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.450638
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.524283
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.498030
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.481482
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.456167
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.503432
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.430852
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.458850
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.429485
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.467234
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.425394
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.461704
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.429307
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.510844
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.467932
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.495950
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.446114
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.481316
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.462361
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.497161
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.450085
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.496502
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.458502
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.478707
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.449040
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.510320
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.458337
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.527578
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.458529
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.501294
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.472510
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.478717
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.443835
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.546437
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.497481
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.501581
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.455374
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.517513
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.486296
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.496277
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.450306
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.506986
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.479016
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.495947
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.462268
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.504241
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.470521
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.499182
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.474223
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.507205
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.466740
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.485155
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.449297
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.518662
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.483917
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.528947
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.488158
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.510667
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.479649
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.509475
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.489940
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.493958
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.456060
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.466640
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.444269
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.523955
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.473439
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.475061
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.445444
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.473653
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.433887
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.458844
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.427230
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.538408
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.495925
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.491735
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.453267
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.537524
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.498118
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.479451
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.441437
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.496674
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.455238
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.485461
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.468001
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.490972
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.456046
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.453574
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.414788
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.510712
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.465433
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.491061
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.463826
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.491994
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.459545
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.494109
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.447970
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.523895
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.491983
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.482286
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.431330
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.501114
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.477839
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.509687
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.472572
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.496472
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.452875
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.504869
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.466995
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.510471
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.472964
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.513501
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.465538
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.511429
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.483954
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.469478
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.449885
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.489296
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.441585
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.477738
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.461034
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.497177
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.461586
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.502054
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.463188
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.493482
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.469931
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.501770
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.458147
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.486593
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.444185
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.518278
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.481459
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.472697
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.436906
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.494758
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.469474
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.459047
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.431698
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.504686
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.471903
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.482973
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.447642
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516849
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.480869
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.526339
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.467875
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.520388
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.470450
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.518418
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.447807
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.485512
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.435149
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.507694
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.469219
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.530646
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.485257
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.510081
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.468167
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.486729
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.466599
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.487506
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.454220
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.452334
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.424477
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.483848
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.435019
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.521668
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.495883
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.492936
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.458414
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.490485
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.451207
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.496984
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.464736
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.500703
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.466727
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.445382
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.408754
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.499794
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.463190
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.504313
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.454356
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.504135
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.473179
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.494424
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.453188
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.472716
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.439405
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.517173
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.491393
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.513543
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.480457
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.488526
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.457542
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.504748
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.449807
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.482255
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.452307
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.458256
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421278
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.488158
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.453669
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.533243
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.488777
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.527164
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.487158
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.485003
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.428585
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.498575
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.468556
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.514686
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.474675
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542575
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.490676
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.512168
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.476345
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.466176
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.432043
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.497487
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.456162
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.506797
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.468120
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.494340
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.443764
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.524476
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.493471
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.498385
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.440843
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.491419
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.465811
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.521613
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.462169
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.477564
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.440251
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.497580
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.456832
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.496015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.460968
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.533264
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.500604
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.525663
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.487147
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.499416
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.476181
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.517695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.484193
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.469816
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.419501
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.492558
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.437322
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.488690
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.454853
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.471696
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.435284
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.514103
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.471973
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.495490
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.472545
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.503309
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.462949
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.488555
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.429584
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.466375
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.419181
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.482932
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.445484
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.494212
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.451503
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.521832
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.494583
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.504904
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.463221
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.504418
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.462102
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.492894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.448799
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.497194
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.452593
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.485351
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.448916
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.438277
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.386849
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.473743
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.450248
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.483323
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.458508
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.485644
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.450371
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.492586
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.445037
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.489116
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.460728
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.518532
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.466702
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.531005
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.462754
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542197
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.502664
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.486052
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.458278
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.495847
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.454519
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.503725
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.470303
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.448214
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.414698
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.477894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.449873
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.478441
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.436741
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.513267
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.479195
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.513531
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.483090
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516427
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.482041
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.500484
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.478606
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.511200
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.466267
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.467053
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.438122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.507978
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.462894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.543868
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.525511
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.480353
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.448997
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.471422
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.432776
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.444455
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.401860
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.515753
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.469662
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.503015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.459550
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.498032
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.466418
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.510226
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.463555
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.512347
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.478884
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.499825
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.450138
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.503541
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.441734
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.474811
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.451033
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.519364
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.484022
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.510413
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.464463
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.483695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.445815
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.463827
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.417830
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.524295
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.473448
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.520484
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.484375
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.452538
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.429374
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.457122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.431038
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.523197
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.478421
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.468609
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.431481
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.503631
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.462663
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.512465
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.482170
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.472025
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.440702
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.494808
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.443475
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.493827
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.464668
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.494600
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.474171
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.491732
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.436842
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.491398
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.457284
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.488404
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.454247
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.507134
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.471090
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.539749
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.467587
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.487466
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.443698
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.511578
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.459458
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.506808
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.478759
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.488872
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.454079
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.498953
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.457984
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.500185
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.465578
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.487499
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.455450
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.504000
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.459296
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.514562
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.479066
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.508669
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.470918
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.490118
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.440227
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.536129
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.481301
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.484332
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.457122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.512135
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.495414
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.496801
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.450579
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.477239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.445096
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.477988
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.451560
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.487007
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.464051
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.497768
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.470883
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.522773
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.481299
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.524455
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.479386
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.535110
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.496778
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.496733
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.453868
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.416548
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.380001
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.494605
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.461699
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.497428
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.469842
#          Iterations 6
# Optimization terminated successfully.
# ...
#          Current function value: 0.475191
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.443978
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.460003
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422344
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.508790
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.466793
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.517343
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.464072
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.494293
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.465415
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515735
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.471596
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.509462
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.480425
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.501902
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.455625
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.525486
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.485017
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.460196
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.423166
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.511845
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.472735
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.533068
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.495644
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.518708
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.461119
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.517467
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.462753
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.492634
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.461811
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.504061
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.468266
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.506847
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.467915
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.504421
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.464819
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.534987
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.501610
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.513629
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.484387
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.531727
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.496331
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.501962
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.476184
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.488145
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.459642
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.507308
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.464861
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.512933
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.483185
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.523231
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.485861
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529018
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.487579
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.505604
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.469625
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.496369
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.469609
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.517491
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.460108
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.528178
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.496762
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.492159
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.459495
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.504551
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.466921
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.504751
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.470054
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.486699
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.460719
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.513426
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.469458
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.512402
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.480958
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.498793
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.466386
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.507789
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.444981
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.498757
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.462365
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.534231
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.500966
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.490219
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.434843
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.526106
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.476563
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.478658
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.438528
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.466196
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.437522
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.474469
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.439663
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.479165
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.438795
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.505503
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.489077
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.537205
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.474317
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.512702
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.473670
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.473659
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.437755
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.498800
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.457419
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.478535
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.442528
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.478965
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.453824
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.523473
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.483089
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.480331
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.452070
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.505346
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.459608
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.468274
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.440792
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.498533
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.473885
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.485575
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.455955
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.490891
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.460211
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.510239
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.467443
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.465073
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.416706
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.518597
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.461726
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.520863
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.494814
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.454449
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.424876
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515000
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.470871
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.518996
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.480104
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.500059
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.466301
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.475035
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.437051
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.491184
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.446648
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.537325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.490849
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.489916
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.446062
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.491682
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.436449
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.524900
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.481070
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.496552
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.455623
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.503428
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.449809
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.514116
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.486363
#          Iterations 6
# Standard errors of the treatment effects:
# [0.19250351 0.06717248 0.00764765 0.06701075 0.16259901]

# %% [markdown]
# We generate 1000 resamples of the data, fit the double logistic regression model to each resample, and store the estimated treatment effects for each covariate. Finally, we calculate the standard deviation of the treatment effects across the resamples as an estimate of the standard error. The output will give you the standard errors for each covariate in the model, representing the difference in the log-odds of survival between first-class passengers and passengers in other classes, controlling for the effects of age, number, and other covariates.
